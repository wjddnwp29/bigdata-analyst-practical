# %% [markdown]
# ## 일원 분산 분석

# %%
import pandas as pd
# df = pd.read_csv("math.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part3/ch6/math.csv")
df.head()
# Out:
#     groups  scores
# 0  group_A      85
# 1  group_A      88
# 2  group_A      90
# 3  group_A      82
# 4  group_A      87

# %%
df
# Out:
#      groups  scores
# 0   group_A      85
# 1   group_A      88
# 2   group_A      90
# 3   group_A      82
# 4   group_A      87
# 5   group_A      89
# 6   group_A      92
# 7   group_A      86
# 8   group_A      88
# 9   group_A      90
# 10  group_B      78
# 11  group_B      80
# 12  group_B      79
# 13  group_B      81
# 14  group_B      80
# 15  group_B      78
# 16  group_B      77
# 17  group_B      79
# 18  group_B      78
# 19  group_B      82
# 20  group_C      80
# 21  group_C      82
# 22  group_C      85
# 23  group_C      84
# 24  group_C      81
# 25  group_C      86
# 26  group_C      82
# 27  group_C      81
# 28  group_C      83
# 29  group_C      80
# 30  group_D      85
# 31  group_D      84
# 32  group_D      86
# 33  group_D      87
# 34  group_D      85
# 35  group_D      86
# 36  group_D      84
# 37  group_D      85
# 38  group_D      87
# 39  group_D      86

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18824\4001917269.py in <module>
#       1 from scipy import stats
# ----> 2 stats.f_oneway(df)
#
# c:\Users\dnwpg\anaconda3\lib\site-packages\scipy\stats\_stats_py.py in f_oneway(axis, *samples)
#    3849     """
#    3850     if len(samples) < 2:
# -> 3851         raise TypeError('at least two inputs are required;'
#    3852                         f' got {len(samples)}.')
#    3853
#
# TypeError: at least two inputs are required; got 1.

# %% [markdown]
# ## 이원 분산 분석

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p3/math.csv")
df.head()
# Out:
#     groups  scores
# 0  group_A      85
# 1  group_A      88
# 2  group_A      90
# 3  group_A      82
# 4  group_A      87

# %% [markdown]
# ## 일원 분산 분석

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p3/math.csv")

from scipy import stats

# 1. Shapiro-Wilk 검정 (정규성)
condA = df['groups']=='group_A'
print(stats.shapiro(df[condA]['scores']))

condB = df['groups']=='group_B'
print(stats.shapiro(df[condB]['scores']))

condC = df['groups']=='group_C'
print(stats.shapiro(df[condC]['scores']))

condD = df['groups']=='group_D'
print(stats.shapiro(df[condD]['scores']))

# 2. Levene 검정 (등분산성)
print(stats.levene(df[condA]['scores'], df[condB]['scores'], df[condC]['scores'], df[condD]['scores']))
# Out:
# ShapiroResult(statistic=0.9715898036956787, pvalue=0.9051811695098877)
# ShapiroResult(statistic=0.9499422907829285, pvalue=0.6678178906440735)
# ShapiroResult(statistic=0.9299424290657043, pvalue=0.44732627272605896)
# ShapiroResult(statistic=0.9065684080123901, pvalue=0.2582412362098694)
# LeveneResult(statistic=1.757685352622062, pvalue=0.17270284963232108)

# %%
df.head()
# Out:
#     groups  scores
# 0  group_A      85
# 1  group_A      88
# 2  group_A      90
# 3  group_A      82
# 4  group_A      87

# %%
from statsmodels.formula.api import ols
model = ols("scores ~ groups",df).fit()

from statsmodels.stats.anova import anova_lm
anova_lm(model)
# Out:
#             df  sum_sq     mean_sq          F        PR(>F)
# groups     3.0   411.8  137.266667  34.174274  1.240642e-10
# Residual  36.0   144.6    4.016667        NaN           NaN

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p3/tomato2.csv")
print(df.head())
# Out:
#   비료유형  물주기  수확량
# 0    A    1  514
# 1    A    1  480
# 2    A    1  507
# 3    A    2  452
# 4    A    2  526

# %%
df.head()
# Out:
#   비료유형  물주기  수확량
# 0    A    1  514
# 1    A    1  480
# 2    A    1  507
# 3    A    2  452
# 4    A    2  526

# %%
from statsmodels.formula.api import ols
model = ols("수확량 ~ 비료유형*물주기",df).fit()

from statsmodels.stats.anova import anova_lm
anova_lm(model)
# Out:
#             df        sum_sq      mean_sq         F    PR(>F)
# 비료유형       2.0   5251.722222  2625.861111  3.264652  0.052143
# 물주기        1.0   6894.422222  6894.422222  8.571622  0.006459
# 비료유형:물주기   2.0   2093.144444  1046.572222  1.301171  0.287135
# Residual  30.0  24129.933333   804.331111       NaN       NaN

# %%
# 일원분산분석을 위한 모델 학습
from statsmodels.formula.api import ols
model = ols('scores ~ groups', df).fit()

# 3~9. ANOVA 테이블
from statsmodels.stats.anova import anova_lm
print(anova_lm(model))
# Out:
#             df  sum_sq     mean_sq          F        PR(>F)
# groups     3.0   411.8  137.266667  34.174274  1.240642e-10
# Residual  36.0   144.6    4.016667        NaN           NaN

# %% [markdown]
# [정답]
# 1. 0.9051811695098877,0.6678178906440735,0.44732627272605896,0.2582412362098694
# 2. 0.17270284963232108
# 3. 기각
# 4. 3
# 5. 36
# 6. 411.8
# 7. 137.266667
# 8. 34.174274
# 9. 1.240642e-10 (0.000000000124)

# %% [markdown]
# ## 이원 분산 분석

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p3/tomato2.csv")
print(df.head())
# Out:
#   비료유형  물주기  수확량
# 0    A    1  514
# 1    A    1  480
# 2    A    1  507
# 3    A    2  452
# 4    A    2  526

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# 1~9 이원 분산 분석
model = ols('수확량 ~ C(비료유형) * C(물주기)', data=df).fit()
anova_table = sm.stats.anova_lm(model)
print(anova_table)
# Out:
#                   df        sum_sq      mean_sq         F    PR(>F)
# C(비료유형)          2.0   5251.722222  2625.861111  3.184685  0.059334
# C(물주기)           3.0   9057.000000  3019.000000  3.661490  0.026460
# C(비료유형):C(물주기)   6.0   4271.833333   711.972222  0.863491  0.535426
# Residual        24.0  19788.666667   824.527778       NaN       NaN

# %% [markdown]
# [정답]
# 1. 3.184685
# 2. 0.059334
# 3. 채택
# 4. 3.661490
# 5. 0.026460
# 6. 기각
# 7. 0.863491
# 8. 0.535426
# 9. 채택
