# %% [markdown]
# ## 적합도 검정

# %%
# import scipy.stats as stats
# ob = [550,250,100,70,30]
# ex = [0.6*1000,0.25*1000,0.08*1000,0.05*1000,0.02*1000]

# print(stats.chisquare(ob,ex))


# import pandas as pd
# df = pd.DataFrame(({
#     "등록" : [50,60],
#     "미등록" : [30,40]
# }), index = ["빅분기","정처기"])
# print(df)

# import scipy.stats as stats
# print(stats.chi2_contingency(df))
# 데이터
# import pandas as pd
# df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p3/camp.csv")


# df = pd.crosstab(df["캠프"],df["등록여부"])
# print(df.head())

# import scipy.stats as s
# print(s.chi2_contingency(df))
# Out:
# Failed to start the Kernel 'Python 3.9.2'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. listen EFAULT: bad address in system call argument :::9008

# %%
# !pip install --upgrade ipykernel
# Out:
# Failed to start the Kernel 'Python 3.9.2'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. listen EFAULT: bad address in system call argument 127.0.0.1:9013

# %% [markdown]
# ## 독립성 검정

# %%
# 1~3
import pandas as pd

# %%
# 4~6
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p3/camp.csv")

# %% [markdown]
# ## 적합도 검정

# %%
# 1. 교통사고 5회 이상 경험 비율
print(30 / 1000)

# 2~4. 적합도 검정
from scipy.stats import chisquare
observed = [550, 250, 100, 70, 30]
expected = [1000*0.60, 1000*0.25, 1000*0.08, 1000*0.05, 1000*0.02]
print(chisquare(observed, expected))
# Out:
# 0.03
# Power_divergenceResult(statistic=np.float64(22.166666666666668), pvalue=np.float64(0.00018567620386641427))

# %% [markdown]
# ## 독립성 검정

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# 1~3. 독립성 검정
observed = pd.DataFrame([[50, 30], [60, 40]])
print(chi2_contingency(observed))
# Out:
# Chi2ContingencyResult(statistic=np.float64(0.03535714285714309), pvalue=np.float64(0.8508492527705047), dof=1, expected_freq=array([[48.88888889, 31.11111111],
#        [61.11111111, 38.88888889]]))

# %%
# 데이터
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p3/camp.csv")
df.head()
# Out:
#     캠프 등록여부
# 0  빅분기   등록
# 1  빅분기   등록
# 2  빅분기   등록
# 3  빅분기   등록
# 4  빅분기   등록

# %%
# 교차표로 변경
df = pd.crosstab(df['캠프'], df['등록여부'])
print(df)

# 4~6. 독립성 검정
print(chi2_contingency(df))
# Out:
# 등록여부  등록  등록안함
# 캠프
# 빅분기   50    30
# 정처기   60    40
# Chi2ContingencyResult(statistic=np.float64(0.03535714285714309), pvalue=np.float64(0.8508492527705047), dof=1, expected_freq=array([[48.88888889, 31.11111111],
#        [61.11111111, 38.88888889]]))
